# %% [markdown]
# <a href="https://colab.research.google.com/github/JamdhadeVikrant/Code/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
data=pd.read_csv('/content/Iris.csv')

# %%
data
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1.0            5.1           3.5            1.4           0.2
# 1      2.0            4.9           3.0            1.4           0.2
# 2      NaN            4.7           3.2            1.3           0.2
# 3      NaN            4.6           3.1            1.5           0.2
# 4      NaN            5.0           3.6            1.4           0.2
# ..     ...            ...           ...            ...           ...
# 145  146.0            6.7           3.0            5.2           2.3
# 146  147.0            6.3           2.5            5.0           1.9
# 147  148.0            6.5           3.0            5.2           2.0
# 148  149.0            6.2           3.4            5.4           2.3
# 149  150.0            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
data.head()
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0  1.0            5.1           3.5            1.4           0.2  Iris-setosa
# 1  2.0            4.9           3.0            1.4           0.2  Iris-setosa
# 2  NaN            4.7           3.2            1.3           0.2  Iris-setosa
# 3  NaN            4.6           3.1            1.5           0.2  Iris-setosa
# 4  NaN            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.head(12)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0    1.0            5.1           3.5            1.4           0.2
# 1    2.0            4.9           3.0            1.4           0.2
# 2    NaN            4.7           3.2            1.3           0.2
# 3    NaN            4.6           3.1            1.5           0.2
# 4    NaN            5.0           3.6            1.4           0.2
# 5    NaN            5.4           3.9            1.7           0.4
# 6    NaN            4.6           3.4            1.4           0.3
# 7    NaN            5.0           3.4            1.5           0.2
# 8    9.0            4.4           2.9            1.4           0.2
# 9   10.0            4.9           3.1            1.5           0.1
# 10  11.0            5.4           3.7            1.5           0.2
# 11  12.0            4.8           3.4            1.6           0.2
#
#         Species
# 0   Iris-setosa
# 1   Iris-setosa
# 2   Iris-setosa
# 3   Iris-setosa
# ...

# %%
data.tail()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146.0            6.7           3.0            5.2           2.3
# 146  147.0            6.3           2.5            5.0           1.9
# 147  148.0            6.5           3.0            5.2           2.0
# 148  149.0            6.2           3.4            5.4           2.3
# 149  150.0            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
data.tail(5)
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146.0            6.7           3.0            5.2           2.3
# 146  147.0            6.3           2.5            5.0           1.9
# 147  148.0            6.5           3.0            5.2           2.0
# 148  149.0            6.2           3.4            5.4           2.3
# 149  150.0            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
data.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
data.shape
# Out:
# (150, 6)

# %%
data.dtypes
# Out:
# Id               float64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
data.columns.values
# Out:
# array(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm',
#        'PetalWidthCm', 'Species'], dtype=object)

# %%
data.describe(include='all')
# Out:
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count   144.000000     150.000000    150.000000     150.000000    150.000000
# unique         NaN            NaN           NaN            NaN           NaN
# top            NaN            NaN           NaN            NaN           NaN
# freq           NaN            NaN           NaN            NaN           NaN
# mean     78.416667       5.843333      3.054000       3.758667      1.198667
# std      41.861827       0.828066      0.433594       1.764420      0.763161
# min       1.000000       4.300000      2.000000       1.000000      0.100000
# 25%      42.750000       5.100000      2.800000       1.600000      0.300000
# 50%      78.500000       5.800000      3.000000       4.350000      1.300000
# 75%     114.250000       6.400000      3.300000       5.100000      1.800000
# max     150.000000       7.900000      4.400000       6.900000      2.500000
#
#             Species
# count           150
# ...

# %%
data["Id"]
# Out:
# 0        1.0
# 1        2.0
# 2        NaN
# 3        NaN
# 4        NaN
#        ...
# 145    146.0
# 146    147.0
# 147    148.0
# 148    149.0
# 149    150.0
# Name: Id, Length: 150, dtype: float64

# %%
data.sort_index(axis=1 ,ascending=False)
# Out:
#             Species  SepalWidthCm  SepalLengthCm  PetalWidthCm  PetalLengthCm  \
# 0       Iris-setosa           3.5            5.1           0.2            1.4
# 1       Iris-setosa           3.0            4.9           0.2            1.4
# 2       Iris-setosa           3.2            4.7           0.2            1.3
# 3       Iris-setosa           3.1            4.6           0.2            1.5
# 4       Iris-setosa           3.6            5.0           0.2            1.4
# ..              ...           ...            ...           ...            ...
# 145  Iris-virginica           3.0            6.7           2.3            5.2
# 146  Iris-virginica           2.5            6.3           1.9            5.0
# 147  Iris-virginica           3.0            6.5           2.0            5.2
# 148  Iris-virginica           3.4            6.2           2.3            5.4
# 149  Iris-virginica           3.0            5.9           1.8            5.1
#
#         Id
# 0      1.0
# ...

# %%
data.iloc[5]
# Out:
# Id                       NaN
# SepalLengthCm            5.4
# SepalWidthCm             3.9
# PetalLengthCm            1.7
# PetalWidthCm             0.4
# Species          Iris-setosa
# Name: 5, dtype: object

# %%
data[0:3]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0  1.0            5.1           3.5            1.4           0.2  Iris-setosa
# 1  2.0            4.9           3.0            1.4           0.2  Iris-setosa
# 2  NaN            4.7           3.2            1.3           0.2  Iris-setosa

# %%
data.iloc[:3, :]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0  1.0            5.1           3.5            1.4           0.2  Iris-setosa
# 1  2.0            4.9           3.0            1.4           0.2  Iris-setosa
# 2  NaN            4.7           3.2            1.3           0.2  Iris-setosa

# %%
data.iloc[:, :4]
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm
# 0      1.0            5.1           3.5            1.4
# 1      2.0            4.9           3.0            1.4
# 2      NaN            4.7           3.2            1.3
# 3      NaN            4.6           3.1            1.5
# 4      NaN            5.0           3.6            1.4
# ..     ...            ...           ...            ...
# 145  146.0            6.7           3.0            5.2
# 146  147.0            6.3           2.5            5.0
# 147  148.0            6.5           3.0            5.2
# 148  149.0            6.2           3.4            5.4
# 149  150.0            5.9           3.0            5.1
#
# [150 rows x 4 columns]

# %%
data.iloc[:10, :4]
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm
# 0   1.0            5.1           3.5            1.4
# 1   2.0            4.9           3.0            1.4
# 2   NaN            4.7           3.2            1.3
# 3   NaN            4.6           3.1            1.5
# 4   NaN            5.0           3.6            1.4
# 5   NaN            5.4           3.9            1.7
# 6   NaN            4.6           3.4            1.4
# 7   NaN            5.0           3.4            1.5
# 8   9.0            4.4           2.9            1.4
# 9  10.0            4.9           3.1            1.5

# %%
data.iloc[3:5,0:2]
# Out:
#    Id  SepalLengthCm
# 3 NaN            4.6
# 4 NaN            5.0

# %%
data.iloc[[1, 2,4], [0, 2]]
# Out:
#     Id  SepalWidthCm
# 1  2.0           3.0
# 2  NaN           3.2
# 4  NaN           3.6

# %%
data.iloc[1:3, :]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1  2.0            4.9           3.0            1.4           0.2  Iris-setosa
# 2  NaN            4.7           3.2            1.3           0.2  Iris-setosa

# %%
data.iloc[:, 1:3]
# Out:
#      SepalLengthCm  SepalWidthCm
# 0              5.1           3.5
# 1              4.9           3.0
# 2              4.7           3.2
# 3              4.6           3.1
# 4              5.0           3.6
# ..             ...           ...
# 145            6.7           3.0
# 146            6.3           2.5
# 147            6.5           3.0
# 148            6.2           3.4
# 149            5.9           3.0
#
# [150 rows x 2 columns]

# %%
data.iloc[1:1]
# Out:
# Empty DataFrame
# Columns: [Id, SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []

# %%
data['SepalLengthCm'].iloc[5]
# Out:
# np.float64(5.4)

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
data.columns.values
# Out:
# array(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm',
#        'PetalWidthCm', 'Species'], dtype=object)

# %%
data.describe(include='all')
# Out:
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count   144.000000     150.000000    150.000000     150.000000    150.000000
# unique         NaN            NaN           NaN            NaN           NaN
# top            NaN            NaN           NaN            NaN           NaN
# freq           NaN            NaN           NaN            NaN           NaN
# mean     78.416667       5.843333      3.054000       3.758667      1.198667
# std      41.861827       0.828066      0.433594       1.764420      0.763161
# min       1.000000       4.300000      2.000000       1.000000      0.100000
# 25%      42.750000       5.100000      2.800000       1.600000      0.300000
# 50%      78.500000       5.800000      3.000000       4.350000      1.300000
# 75%     114.250000       6.400000      3.300000       5.100000      1.800000
# max     150.000000       7.900000      4.400000       6.900000      2.500000
#
#             Species
# count           150
# ...

# %%
data["Id"]
# Out:
# 0        1.0
# 1        2.0
# 2        NaN
# 3        NaN
# 4        NaN
#        ...
# 145    146.0
# 146    147.0
# 147    148.0
# 148    149.0
# 149    150.0
# Name: Id, Length: 150, dtype: float64

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
data.loc[:, ["Id","Species"]]
# Out:
#         Id         Species
# 0      1.0     Iris-setosa
# 1      2.0     Iris-setosa
# 2      NaN     Iris-setosa
# 3      NaN     Iris-setosa
# 4      NaN     Iris-setosa
# ..     ...             ...
# 145  146.0  Iris-virginica
# 146  147.0  Iris-virginica
# 147  148.0  Iris-virginica
# 148  149.0  Iris-virginica
# 149  150.0  Iris-virginica
#
# [150 rows x 2 columns]

# %%
data.iloc[1:3, :]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1  2.0            4.9           3.0            1.4           0.2  Iris-setosa
# 2  NaN            4.7           3.2            1.3           0.2  Iris-setosa

# %%
data.iloc[:, 1:3]
# Out:
#      SepalLengthCm  SepalWidthCm
# 0              5.1           3.5
# 1              4.9           3.0
# 2              4.7           3.2
# 3              4.6           3.1
# 4              5.0           3.6
# ..             ...           ...
# 145            6.7           3.0
# 146            6.3           2.5
# 147            6.5           3.0
# 148            6.2           3.4
# 149            5.9           3.0
#
# [150 rows x 2 columns]

# %%
data.iloc[1, 1]
# Out:
# np.float64(4.9)

# %%
data['SepalLengthCm'].iloc[5]
# Out:
# np.float64(5.4)

# %%
cols_2_4=data.columns[2:4]
data[cols_2_4]
# Out:
#      SepalWidthCm  PetalLengthCm
# 0             3.5            1.4
# 1             3.0            1.4
# 2             3.2            1.3
# 3             3.1            1.5
# 4             3.6            1.4
# ..            ...            ...
# 145           3.0            5.2
# 146           2.5            5.0
# 147           3.0            5.2
# 148           3.4            5.4
# 149           3.0            5.1
#
# [150 rows x 2 columns]

# %%
data.sort_values(by="Id")
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0    1.0            5.1           3.5            1.4           0.2
# 1    2.0            4.9           3.0            1.4           0.2
# 8    9.0            4.4           2.9            1.4           0.2
# 9   10.0            4.9           3.1            1.5           0.1
# 10  11.0            5.4           3.7            1.5           0.2
# ..   ...            ...           ...            ...           ...
# 3    NaN            4.6           3.1            1.5           0.2
# 4    NaN            5.0           3.6            1.4           0.2
# 5    NaN            5.4           3.9            1.7           0.4
# 6    NaN            4.6           3.4            1.4           0.3
# 7    NaN            5.0           3.4            1.5           0.2
#
#         Species
# 0   Iris-setosa
# 1   Iris-setosa
# 8   Iris-setosa
# 9   Iris-setosa
# 10  Iris-setosa
# ..          ...
# 3   Iris-setosa
# 4   Iris-setosa
# ...

# %%
data.iloc[[1, 2,4], [0, 2]]
# Out:
#     Id  SepalWidthCm
# 1  2.0           3.0
# 2  NaN           3.2
# 4  NaN           3.6

# %%
data.iloc[1:3, :]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1  2.0            4.9           3.0            1.4           0.2  Iris-setosa
# 2  NaN            4.7           3.2            1.3           0.2  Iris-setosa

# %%
data[data.columns[2:4]].iloc[5:10]
# Out:
#    SepalWidthCm  PetalLengthCm
# 5           3.9            1.7
# 6           3.4            1.4
# 7           3.4            1.5
# 8           2.9            1.4
# 9           3.1            1.5

# %%
data.head()
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0  1.0            5.1           3.5            1.4           0.2  Iris-setosa
# 1  2.0            4.9           3.0            1.4           0.2  Iris-setosa
# 2  NaN            4.7           3.2            1.3           0.2  Iris-setosa
# 3  NaN            4.6           3.1            1.5           0.2  Iris-setosa
# 4  NaN            5.0           3.6            1.4           0.2  Iris-setosa

# %%
import pandas as pd
from sklearn import preprocessing

# %%
min_max_scaler = preprocessing.MinMaxScaler()

# %%
x=data.iloc[:,:4]

# %%
x_scaled = min_max_scaler.fit_transform(x)

# %%
df_normalized = pd.DataFrame(x_scaled)

# %%
df_normalized
# Out:
#             0         1         2         3
# 0    0.000000  0.222222  0.625000  0.067797
# 1    0.006711  0.166667  0.416667  0.067797
# 2         NaN  0.111111  0.500000  0.050847
# 3         NaN  0.083333  0.458333  0.084746
# 4         NaN  0.194444  0.666667  0.067797
# ..        ...       ...       ...       ...
# 145  0.973154  0.666667  0.416667  0.711864
# 146  0.979866  0.555556  0.208333  0.677966
# 147  0.986577  0.611111  0.416667  0.711864
# 148  0.993289  0.527778  0.583333  0.745763
# 149  1.000000  0.444444  0.416667  0.694915
#
# [150 rows x 4 columns]

# %%
data_normalized = pd.DataFrame(x_scaled)

# %%
data_normalized
# Out:
#             0         1         2         3
# 0    0.000000  0.222222  0.625000  0.067797
# 1    0.006711  0.166667  0.416667  0.067797
# 2         NaN  0.111111  0.500000  0.050847
# 3         NaN  0.083333  0.458333  0.084746
# 4         NaN  0.194444  0.666667  0.067797
# ..        ...       ...       ...       ...
# 145  0.973154  0.666667  0.416667  0.711864
# 146  0.979866  0.555556  0.208333  0.677966
# 147  0.986577  0.611111  0.416667  0.711864
# 148  0.993289  0.527778  0.583333  0.745763
# 149  1.000000  0.444444  0.416667  0.694915
#
# [150 rows x 4 columns]

# %%
data['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
data['Species']= label_encoder.fit_transform(data['Species'])

# %%
data['Species'].unique()
# Out:
# array([0, 1, 2])

# %%
data['Species'].unique()
# Out:
# array([0, 1, 2])

# %%
features_data=data.drop(columns=['Species'])

# %%
enc = preprocessing.OneHotEncoder()

# %%
enc_df=pd.DataFrame(enc.fit_transform(data[['Species']]))

# %%
df_encode = features_data.join(enc_df)

# %%
df_encode
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1.0            5.1           3.5            1.4           0.2
# 1      2.0            4.9           3.0            1.4           0.2
# 2      NaN            4.7           3.2            1.3           0.2
# 3      NaN            4.6           3.1            1.5           0.2
# 4      NaN            5.0           3.6            1.4           0.2
# ..     ...            ...           ...            ...           ...
# 145  146.0            6.7           3.0            5.2           2.3
# 146  147.0            6.3           2.5            5.0           1.9
# 147  148.0            6.5           3.0            5.2           2.0
# 148  149.0            6.2           3.4            5.4           2.3
# 149  150.0            5.9           3.0            5.1           1.8
#
#                                                      0
# 0    <Compressed Sparse Row sparse matrix of dtype ...
# ...

# %%
df_encode.rename(columns = {0:'Iris-Setosa',
1:'Iris-Versicolor',2:'Iris-virginica'}, inplace = True)

# %%
df_encode
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1.0            5.1           3.5            1.4           0.2
# 1      2.0            4.9           3.0            1.4           0.2
# 2      NaN            4.7           3.2            1.3           0.2
# 3      NaN            4.6           3.1            1.5           0.2
# 4      NaN            5.0           3.6            1.4           0.2
# ..     ...            ...           ...            ...           ...
# 145  146.0            6.7           3.0            5.2           2.3
# 146  147.0            6.3           2.5            5.0           1.9
# 147  148.0            6.5           3.0            5.2           2.0
# 148  149.0            6.2           3.4            5.4           2.3
# 149  150.0            5.9           3.0            5.1           1.8
#
#                                            Iris-Setosa
# 0    <Compressed Sparse Row sparse matrix of dtype ...
# ...

# %%
data['Species'].unique()
# Out:
# array([0, 1, 2])

# %%
one_hot_df = pd.get_dummies(data, prefix="Species",
columns=['Species'], drop_first=True)

# %%
one_hot_df
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1.0            5.1           3.5            1.4           0.2
# 1      2.0            4.9           3.0            1.4           0.2
# 2      NaN            4.7           3.2            1.3           0.2
# 3      NaN            4.6           3.1            1.5           0.2
# 4      NaN            5.0           3.6            1.4           0.2
# ..     ...            ...           ...            ...           ...
# 145  146.0            6.7           3.0            5.2           2.3
# 146  147.0            6.3           2.5            5.0           1.9
# 147  148.0            6.5           3.0            5.2           2.0
# 148  149.0            6.2           3.4            5.4           2.3
# 149  150.0            5.9           3.0            5.1           1.8
#
#      Species_1  Species_2
# 0        False      False
# 1        False      False
# 2        False      False
# 3        False      False
# ...
